# %% [markdown]
# <a href="https://colab.research.google.com/github/ingridmidory/ingridmidory/blob/main/Horario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files. upload ()
# Out:
#      <input type="file" id="files-615defc4-e9a5-416d-9cde-5940d27930af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-615defc4-e9a5-416d-9cde-5940d27930af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('Ejercicio.csv')
print (df)
# Out:
#                            NOMBRE  CLAVE GRUPO    H1    S1    H2    S2    H3  \
# 0                         Profe 1   1502   505  MI01  B216  VI01  A206  MI02
# 1                         Profe 1   1502   508  LU02  A207  LU03  A207  MI03
# 2                         Profe 1   1502   512  MI05  B216  MI06  B216  VI06
# 3                         Profe 1   1613   605  MI04  B308  VI04  A206  VI05
# 4                         Profe 1   1613   607  MI08  B112  LU04  A206  MI07
# 5                         Profe 1   1613   656  MA12  A207  JU12  A207  MA13
# 6                         Profe 2   1404   415  MI02  B108  MI03  B108  MA05
# 7                         Profe 2   1512   505  LU03  B212  MA03  B206   NaN
# 8                         Profe 2   1512   509  MI04  B206  JU04  B213   NaN
# 9                         Profe 2   1512   516  LU02  B213  MA02  B206   NaN
# 10                        Profe 2   1618   615  LU01  B307  JU01  B315  JU02
# ...

# %%
Lista_valores = df.values.tolist ()

# %%
Lista_valores
# Out:
# [['Profe 1',
#   1502,
#   '505',
#   'MI01',
#   'B216',
#   'VI01',
#   'A206',
#   'MI02',
#   'B216',
#   'VI02',
#   'A206',
#   nan,
#   nan,
#   nan],
#  ['Profe 1',
#   1502,
#   '508',
#   'LU02',
#   'A207',
#   'LU03',
#   'A207',
#   'MI03',
#   'B212',
#   'JU01',
#   'B208',
#   nan,
#   nan,
#   nan],
#  ['Profe 1',
#   1502,
#   '512',
#   'MI05',
#   'B216',
#   'MI06',
#   'B216',
#   'VI06',
#   'A207',
#   'VI07',
#   'A207',
#   nan,
#   nan,
#   nan],
#  ['Profe 1',
#   1613,
#   '605',
#   'MI04',
#   'B308',
#   'VI04',
#   'A206',
#   'VI05',
#   'A206',
#   'MA07',
#   'A207',
#   nan,
#   nan,
#   nan],
#  ['Profe 1',
#   1613,
#   '607',
#   'MI08',
#   'B112',
#   'LU04',
#   'A206',
#   'MI07',
#   'B112',
#   'VI03',
#   'B311',
#   nan,
#   nan,
#   nan],
#  ['Profe 1',
#   1613,
#   '656',
#   'MA12',
#   'A207',
#   'JU12',
#   'A207',
#   'MA13',
#   'A207',
#   'JU13',
#   'B310',
#   nan,
#   nan,
#   nan],
#  ['Profe 2',
#   1404,
#   '415',
# ...

# %%
from tabulate import tabulate 
datos = [[]]
